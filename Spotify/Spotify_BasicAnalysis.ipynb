# %% [markdown]
# The goal of this notebook is to showcase some common data manipulation operations using Pandas

# %%
import os
os.chdir(r'D:\Work\Kaggle\top50spotify2019')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#Get the files
data = pd.read_excel(r'top50.xlsx')
#test = pd.read_csv('test_V2.csv')

# %%
data.drop(['Unnamed: 0'], inplace=True, axis=1)

# %% [markdown]
# Best Song based on Popularity

# %%
data.sort_values('Popularity', ascending=False).head(1)['Track.Name']
# Out:
# 9    bad guy
# Name: Track.Name, dtype: object

# %% [markdown]
# Best Artist based on Popularity

# %%
data.sort_values('Popularity', ascending=False).head(1)['Artist.Name']
# Out:
# 9    Billie Eilish
# Name: Artist.Name, dtype: object

# %% [markdown]
# Best Genre based on Popularity

# %%
data.sort_values('Popularity', ascending=False).head(1)['Genre']
# Out:
# 9    electropop
# Name: Genre, dtype: object

# %% [markdown]
# Most Common Genre

# %%
data['Genre'].mode()
# Out:
# 0    dance pop
# dtype: object

# %% [markdown]
# Song - Maximum Length

# %%
data[data['Length.'] == max(data['Length.'])][['Track.Name','Artist.Name']] # in seconds
# Out:
#               Track.Name  Artist.Name
# 22  No Me Conoce - Remix  Jhay Cortez

# %% [markdown]
# Song - Minimum Length

# %%
data[data['Length.'] == min(data['Length.'])][['Track.Name','Artist.Name']] # in seconds
# Out:
#    Track.Name Artist.Name
# 21     Panini   Lil Nas X

# %% [markdown]
# Find the most popular music according to Genre

# %%
data.sort_values(['Popularity','Genre'], ascending=False).drop_duplicates('Genre').set_index('Genre')['Track.Name']
# Out:
# Genre
# electropop                                                    bad guy
# dfw rap                                   Goodbyes (Feat. Young Thug)
# reggaeton                                                    Callaita
# trap music                                                     Ransom
# reggaeton flow                                                  China
# canadian hip hop             Money In The Grave (Drake ft. Rick Ross)
# pop house                                         Piece Of Your Heart
# panamanian pop                                             Otro Trago
# latin                                                 Soltera - Remix
# escape room                                               Truth Hurts
# country rap                                                    Panini
# pop                                                 How Do You Sleep?
# dance pop                                       You Need To Calm Down
# ...

# %% [markdown]
# Word Cloud of Genre

# %%
from wordcloud import WordCloud
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                min_font_size = 10).generate(str(data['Genre'].to_list()))

# %%
plt.figure(figsize=(8,8))
plt.imshow(wordcloud)
